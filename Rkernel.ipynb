# %%
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd

# %%
datarad = pd.read_csv('data.csv')
print(datarad.head(10))
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6  https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 7  https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 8  https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 9  https://cdn.sofifa.org/players/4/19/200389.png    Slovenia
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
# 5   https://cdn.sofifa.org/flags/7.png       91         91
# 6  https://cdn.sofifa.org/flags/10.png       91         91
# 7  https://cdn.sofifa.org/flags/60.png       91         91
# 8  https://cdn.sofifa.org/flags/45.png       91         91
# 9  https://cdn.sofifa.org/flags/44.png       90         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
# 5              Chelsea  ...      91.0    34.0           27.0           22.0
# 6          Real Madrid  ...      84.0    60.0           76.0           73.0
# 7         FC Barcelona  ...      85.0    62.0           45.0           38.0
# 8          Real Madrid  ...      82.0    87.0           92.0           91.0
# 9      Atlético Madrid  ...      70.0    27.0           12.0           18.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
# 5     11.0        12.0        6.0            8.0        8.0        €172.1M
# 6     13.0         9.0        7.0           14.0        9.0        €137.4M
# 7     27.0        25.0       31.0           33.0       37.0          €164M
# 8     11.0         8.0        9.0            7.0       11.0        €104.6M
# 9     86.0        92.0       78.0           88.0       89.0        €144.5M
#
# [10 rows x 89 columns]

# %%
library('plotly')
rad = datarad[c('Name', 'Finishing', 'Dribbling', 'SprintSpeed', 'ShortPassing', 'StandingTackle')]
cat("\nEnter name of player 1: ")
player1 = readline()
cat("\nEnter name of player 2: ")
player2 = readline()

cmp = rad[(rad$Name==player1), c('Finishing', 'Dribbling', 'SprintSpeed', 'ShortPassing', 'StandingTackle')]
cmp
cmp = rbind(cmp, rad[(rad$Name==player2), c('Finishing', 'Dribbling', 'SprintSpeed', 'ShortPassing', 'StandingTackle')])
pc1=c(cmp$Finishing[1], cmp$Dribbling[1], cmp$SprintSpeed[1], cmp$ShortPassing[1], cmp$StandingTackle[1])
pc2=c(cmp$Finishing[2], cmp$Dribbling[2], cmp$SprintSpeed[2], cmp$ShortPassing[2], cmp$StandingTackle[2])
typeof(pc1)
pc2
p = plot_ly(type='scatterpolar', fill='toself') %>% 
    add_trace(r=pc1, theta = c('Shoot', 'Movement', 'Pace', 'Passing', 'Defence'), name=player1) %>%
    add_trace(r=pc2, theta = c('Shoot', 'Movement', 'Pace', 'Passing', 'Defence'), name=player2) %>%
    layout(polar = list(radialaxis = list(visible = T, range=c(0,100))))
print(p)
# Out:
#   File "<ipython-input-8-709e259adf3e>", line 8
#     cmp = rad[(rad$Name==player1), c('Finishing', 'Dribbling', 'SprintSpeed', 'ShortPassing', 'StandingTackle')]
#                   ^
# SyntaxError: invalid syntax

# %%
data = read.csv('./team.csv')
head(data)
# Out:
#   full_name               age birthday  league         season    position
# 1 David de Gea            29  657964800 Premier League 2018/2019 Goalkeeper
# 2 Matteo Darmian          30  628588800 Premier League 2018/2019 Defender
# 3 Victor Nilsson Lindelöf 25  774428400 Premier League 2018/2019 Defender
# 4 Luke Shaw               24  805532400 Premier League 2018/2019 Defender
# 5 Eric Bertrand Bailly    26  766134000 Premier League 2018/2019 Defender
# 6 Juan Mata               31  578214000 Premier League 2018/2019 Midfielder
#   club_name         minutes_played_overall minutes_played_home
# 1 Manchester United 3420                   1710
# 2 Manchester United  443                    353
# 3 Manchester United 2602                   1112
# 4 Manchester United 2592                   1170
# 5 Manchester United  637                    349
# 6 Manchester United 1294                    833
#   minutes_played_away ⋯ conceded_per_90_overall min_per_conceded_overall
# 1 1710                ⋯ 1.34                    67
# 2   90                ⋯ 1.42                    63
# 3 1490                ⋯ 1.31                    68
# 4 1422                ⋯ 1.25                    72
# 5  288                ⋯ 1.70                    53
# 6  461                ⋯ 0.97                    92
#   min_per_match min_per_card_overall min_per_assist_overall
# 1 90            3420                    0
# 2 74               0                    0
# 3 87            2602                 2602
# 4 89             236                  648
# 5 53             319                    0
# 6 59             431                  647
#   cards_per_90_overall rank_in_league_top_attackers
# 1 0.03                 310
# 2 0.00                 411
# 3 0.03                 263
# 4 0.38                 262
# 5 0.28                 340
# 6 0.21                  91
#   rank_in_league_top_midfielders rank_in_league_top_defenders
# 1 419                             90
# 2 366                            102
# 3 249                             88
# 4 104                             79
# 5 271                            142
# 6 100                             -1
#   rank_in_club_top_scorer
# 1 18
# 2 25
# 3 14
# 4 13
# 5 26
# 6  6

# %%
# cat("\nEnter Team name: ")
# tn = readline()
tn = "Manchester United"
team= data[data$club_name==tn, c('full_name', 'appearances_overall', 'goals_overall', 'assists_overall')]
team
tmp=0
while(tmp<1){
    cat("\n1. Goals contribution\n2. Assist Contribution\n3. Appearances\n4. Exit\nEnter Choice")
    ch = readline()
    if(ch==1) {
        total=sum(team$goals_overall)
        goaldat=team[(team$Goals>4), c('full_name', 'goals_overall')]
        tot2 = sum(goaldat$goals_overall)
        
        others = total-tot2
        player = as.vector(goaldat$full_name)
        player = c(player, 'Others')
        player = player[-1]
        goalbyplayer = as.vector(goaldat$goals_overall)
        goalbyplayer=c(goalbyplayer,others)
        goalbyplayer=goalbyplayer[-1]
        cat(goalbyplayer)
        cat(player)
        #pie(goalbyplayer, player)
    }
}
# Out:
#     full_name                    appearances_overall goals_overall
# 1   David de Gea                 38                   0
# 2   Matteo Darmian                6                   0
# 3   Victor Nilsson Lindelöf      30                   1
# 4   Luke Shaw                    29                   1
# 5   Eric Bertrand Bailly         12                   0
# 6   Juan Mata                    22                   3
# 7   Paul Pogba                   35                  13
# 8   Frederico Rodrigues Santos   17                   1
# 9   Andreas Pereira              15                   1
# 10  Alexis Sanchez               20                   1
# 11  Marcus Rashford              33                  10
# 12  Romelu Lukaku                32                  12
# 13  Scott McTominay              16                   2
# 14  Marouane Fellaini            14                   0
# 15  Anthony Martial              27                  10
# 16  Chris Smalling               24                   1
# 17  Lee Grant                     0                   0
# 18  Ashley Young                 30                   2
# 391 Jesse Lingard                27                   4
# 392 Ander Herrera                22                   2
# 411 Antonio Valencia              6                   0
# 412 Phil Jones                   18                   0
# 413 Nemanja Matić                28                   1
# 432 Sergio Germán Romero          0                   0
# 470 Faustino Marcos Alberto Rojo  5                   0
# 483 José Diogo Dalot Teixeira    16                   0
# 501 Angel Gomes                   2                   0
# 546 James Garner                  1                   0
# 547 Tahith Chong                  2                   0
# 553 Mason Greenwood               3                   0
#     assists_overall
# 1   0
# 2   0
# 3   1
# 4   4
# 5   0
# 6   2
# 7   9
# 8   1
# 9   1
# 10  3
# 11  6
# 12  0
# 13  0
# 14  1
# 15  2
# 16  0
# 17  0
# 18  2
# 391 2
# 392 3
# 411 0
# 412 1
# 413 0
# 432 0
# 470 0
# 483 2
# 501 0
# 546 0
# 547 0
# 553 0
# 1
